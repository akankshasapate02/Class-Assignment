# %%
#Question 01
x = int(input("Enter a number: "))
print("You Entered a integer: ",x)
# Out:
# You Entered a integer:  10

# %%
#Question 02
x = input("Enter a String: ")
print("You entered String :",x)
# Out:
# You entered String : Core2web

# %%
#Question 03
x = float(input("Enter a float number: "))
print("You entered float : ",x)
# Out:
# You entered float :  12.5

# %%
#Question 04
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
sum = num1+num2
print(f"Sum of {num1} and {num2} is {sum}")
# Out:
# Sum of 5 and 10 is 15

# %%
#Question 05
name = input("Enter name: ")
age = int(input("Enter age: "))
print("Name: ",name)
print("Age: ",age)
# Out:
# Name:  Core2web
# Age:  8

# %%
#Question 06
num1 = float(input("Enter a float number: "))
num2 = float(input("Enter a float number: "))
num3 = float(input("Enter a float number: "))
avg = (num1+num2+num3)/3
print("Average of number is ",avg)
# Out:
# Average of number is  3.3333333333333335

# %%
#Question 07
x = int(input("Enter a number: "))
typeN = type(x)
print("The Type of entered value is ",typeN)
# Out:
# The Type of entered value is  <class 'int'>

# %%
#Question 08
x = input("Enter a String: ")
typeS = type(x)
print("The Type of entered value is ",typeS)
# Out:
# The Type of entered value is  <class 'str'>

# %%
#Question 09
num1 = float(input("Enter a float number: "))
typeN = type(num1)
print("The Type of entered value is ",typeN)
# Out:
# The Type of entered value is  <class 'float'>

# %%
#Question 10
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
print(f"Multiplication of {num1} and {num2} is {num1*num2}")
# Out:
# Multiplication of 4 and 6 is 24
