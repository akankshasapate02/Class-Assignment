# %%
# Question 01

x = 10
y = 20

print(x+y)
# Out:
# 30

# %%
# Question 02

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)
# Out:
# Given number is grater than 0 :  10

# %%
# Question 03

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)
    if x>0:
        print("Given number is grater than 0 : ",x)
# Out:
# Given number is grater than 0 :  12
# Given number is grater than 0 :  12

# %%
# Question 04

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)

else:
    print("Given number is less than 0 :",x )
# Out:
# Given number is grater than 0 :  45

# %%
# Question 05

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)

else:
    print("Given number is less than 0 :",x )
# Out:
# Given number is less than 0 : -5

# %%
# Question 06

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)

else:
    print("Given number is less than 0 : ",x)
# Out:
# Given number is grater than 0 :  10

# %%
# Question 07

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)

if x==0:
    print("Given number is  equal of 0 : ",x)

if x<0:
    print("Given number is less than 0 : ",x)
# Out:
# Given number is  equal of 0 :  0

# %%
# Question 08

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)
elif x==0:
    print("Given number is equal of 0 : ",x)

else:
    print("Given number is less than 0 : ",x)
# Out:
# Given number is grater than 0 :  2

# %%
# Question 09

x = int(input("Enter number : "))

if x>0:
    print("Given number is grater than 0 : ",x)
elif x==0:
    print("Given number is equal of 0 : ",x)

else:
    print("Given number is less than 0 : ",x)
# Out:
# Given number is less than 0 :  -6

# %%
# Question 10

num1 = 10
num2 = 20

sumData = num1+num2
subData = num2-num1

if num1>num2:
    print(sumData)

else :
    print(subData)
# Out:
# 10
