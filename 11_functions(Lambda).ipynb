# %%
# Question 01

l = int(input("Enter length of area: "))

area_of_sq = lambda l : l*l
print(area_of_sq(l))
# Out:
# 16

# %%
# Question 02

num = int(input("Enter a number : "))

cube = lambda a : a**3

print(cube(num))

# %%
# Question 03

# %%
# Question 04

# %%
# Question 05

# %%
# Question 06

# %%
# Question 07

# %%
# Question 08

# %%
# Question 09

# %%
# Question 10
